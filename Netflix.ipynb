# %%
import pandas as pd

# %%
import os
current_directory = os.getcwd()
file_path = os.path.join(current_directory, 'Netflix Data.csv')
print(file_path) # to verify the path
# Out:
# /content/Netflix Data.csv

# %%
import pandas as pd
from google.colab import files

uploaded = files.upload()

for fn in uploaded.keys():
  print('User uploaded file "{name}" with length {length} bytes'.format(
      name=fn, length=len(uploaded[fn])))

# Assuming your CSV file is named 'your_file.csv'
# Check if the file content is not empty
with open('Netflix Data.csv', 'r') as f:
    content = f.read()
    if not content.strip():  # Check if file is empty after removing whitespace
        print("Error: The uploaded file is empty.")
        # Handle the empty file case, e.g., ask user to re-upload, or create a default DataFrame
    else:
        df = pd.read_csv('Netflix Data.csv')
        print(df.head())  # Print the first few rows to check if it loaded correctly
# Out:
#      <input type="file" id="files-05826121-60b0-4070-8b2c-b3c0d8613147" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-05826121-60b0-4070-8b2c-b3c0d8613147">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
data=pd.read_csv('Netflix Data.csv')

# %%
data
# Out:
#      Show_Id Category                                    Title  \
# 0         s1  TV Show                                       3%
# 1         s2    Movie                                    07:19
# 2         s3    Movie                                    23:59
# 3         s4    Movie                                        9
# 4         s5    Movie                                       21
# ...      ...      ...                                      ...
# 7784   s7783    Movie                                     Zozo
# 7785   s7784    Movie                                   Zubaan
# 7786   s7785    Movie                        Zulu Man in Japan
# 7787   s7786  TV Show                    Zumbo's Just Desserts
# 7788   s7787    Movie  ZZ TOP: THAT LITTLE OL' BAND FROM TEXAS
#
#                Director                                               Cast  \
# 0                   NaN  João Miguel, Bianca Comparato, Michel Gomes, R...
# ...

# %%
data.head(5)
# Out:
#   Show_Id Category  Title           Director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie  07:19  Jorge Michel Grau
# 2      s3    Movie  23:59       Gilbert Chan
# 3      s4    Movie      9        Shane Acker
# 4      s5    Movie     21     Robert Luketic
#
#                                                 Cast        Country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...         Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...         Mexico
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...      Singapore
# 3  Elijah Wood, John C. Reilly, Jennifer Connelly...  United States
# 4  Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...  United States
#
#         Release_Date Rating   Duration  \
# 0    August 14, 2020  TV-MA  4 Seasons
# 1  December 23, 2016  TV-MA     93 min
# 2  December 20, 2018      R     78 min
# 3  November 16, 2017  PG-13     80 min
# 4    January 1, 2020  PG-13    123 min
#
# ...

# %%
data.isnull().sum()
# Out:
# Show_Id            0
# Category           0
# Title              0
# Director        2388
# Cast             718
# Country          507
# Release_Date      10
# Rating             7
# Duration           0
# Type               0
# Description        0
# dtype: int64

# %%
data.dtypes
# Out:
# Show_Id         object
# Category        object
# Title           object
# Director        object
# Cast            object
# Country         object
# Release_Date    object
# Rating          object
# Duration        object
# Type            object
# Description     object
# dtype: object

# %%
data.nunique()
# Out:
# Show_Id         7787
# Category           2
# Title           7787
# Director        4050
# Cast            6831
# Country          681
# Release_Date    1565
# Rating            14
# Duration         216
# Type             492
# Description     7769
# dtype: int64

# %%
import pandas as pd

# %%
data=pd.read_csv('Netflix Data.csv')
data
# Out:
#      Show_Id Category                                    Title  \
# 0         s1  TV Show                                       3%
# 1         s2    Movie                                    07:19
# 2         s3    Movie                                    23:59
# 3         s4    Movie                                        9
# 4         s5    Movie                                       21
# ...      ...      ...                                      ...
# 7784   s7783    Movie                                     Zozo
# 7785   s7784    Movie                                   Zubaan
# 7786   s7785    Movie                        Zulu Man in Japan
# 7787   s7786  TV Show                    Zumbo's Just Desserts
# 7788   s7787    Movie  ZZ TOP: THAT LITTLE OL' BAND FROM TEXAS
#
#                Director                                               Cast  \
# 0                   NaN  João Miguel, Bianca Comparato, Michel Gomes, R...
# ...

# %%
 data['Release_Year']=pd.to_datetime(data['Release_Date'],errors='coerce').dt.year

# %%
data[data['Release_Year']>2015]
# Out:
#      Show_Id Category                                    Title  \
# 0         s1  TV Show                                       3%
# 1         s2    Movie                                    07:19
# 2         s3    Movie                                    23:59
# 3         s4    Movie                                        9
# 4         s5    Movie                                       21
# ...      ...      ...                                      ...
# 7784   s7783    Movie                                     Zozo
# 7785   s7784    Movie                                   Zubaan
# 7786   s7785    Movie                        Zulu Man in Japan
# 7787   s7786  TV Show                    Zumbo's Just Desserts
# 7788   s7787    Movie  ZZ TOP: THAT LITTLE OL' BAND FROM TEXAS
#
#                Director                                               Cast  \
# 0                   NaN  João Miguel, Bianca Comparato, Michel Gomes, R...
# ...

# %%
data[data['Title'].str.contains('Love',case=False,na=False)]
# Out:
#      Show_Id Category                             Title  \
# 198     s199  TV Show  A Little Thing Called First Love
# 199     s200  TV Show               A Love So Beautiful
# 200     s201    Movie           A Love Song for Latasha
# 201     s202    Movie                      A Love Story
# 223     s224    Movie                     A Secret Love
# ...      ...      ...                               ...
# 7558   s7557  TV Show                     What Is Love?
# 7568   s7567  TV Show   What the Love! with Karan Johar
# 7574   s7573    Movie              What's Up With Love?
# 7584   s7583    Movie                 When Love Happens
# 7667   s7666    Movie                World Famous Lover
#
#                        Director  \
# 198                         NaN
# 199                         NaN
# 200        Sophia Nahli Allison
# 201       Maryo J. De los Reyes
# 223                 Chris Bolan
# ...                         ...
# 7558                        NaN
# ...

# %%
import pandas as pd

# %%
data=pd.read_csv('Netflix Data.csv')
data
# Out:
#      Show_Id Category                                    Title  \
# 0         s1  TV Show                                       3%
# 1         s2    Movie                                    07:19
# 2         s3    Movie                                    23:59
# 3         s4    Movie                                        9
# 4         s5    Movie                                       21
# ...      ...      ...                                      ...
# 7784   s7783    Movie                                     Zozo
# 7785   s7784    Movie                                   Zubaan
# 7786   s7785    Movie                        Zulu Man in Japan
# 7787   s7786  TV Show                    Zumbo's Just Desserts
# 7788   s7787    Movie  ZZ TOP: THAT LITTLE OL' BAND FROM TEXAS
#
#                Director                                               Cast  \
# 0                   NaN  João Miguel, Bianca Comparato, Michel Gomes, R...
# ...

# %%
data[data['Category']=='TV Show']['Country'].value_counts().head(5)
# Out:
# Country
# United States     705
# United Kingdom    204
# Japan             157
# South Korea       147
# India              71
# Name: count, dtype: int64

# %%
import pandas as pd
from google.colab import files

uploaded = files.upload()

for fn in uploaded.keys():
  print('User uploaded file "{name}" with length {length} bytes'.format(
      name=fn, length=len(uploaded[fn])))

# Assuming your CSV file is named 'your_file.csv'
# Check if the file content is not empty
with open('Netflix Data.csv', 'r') as f:
    content = f.read()
    if not content.strip():  # Check if file is empty after removing whitespace
        print("Error: The uploaded file is empty.")
        # Handle the empty file case, e.g., ask user to re-upload, or create a default DataFrame
    else:
        df = pd.read_csv('Netflix Data.csv')
        print(df.head())  # Print the first few rows to check if it loaded correctly
# Out:
#      <input type="file" id="files-f437ff07-0c6d-4d4f-aefe-3e2efc5860b5" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-f437ff07-0c6d-4d4f-aefe-3e2efc5860b5">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
data=pd.read_csv('Netflix Data.csv')
data
# Out:
#      Show_Id Category                                    Title  \
# 0         s1  TV Show                                       3%
# 1         s2    Movie                                    07:19
# 2         s3    Movie                                    23:59
# 3         s4    Movie                                        9
# 4         s5    Movie                                       21
# ...      ...      ...                                      ...
# 7784   s7783    Movie                                     Zozo
# 7785   s7784    Movie                                   Zubaan
# 7786   s7785    Movie                        Zulu Man in Japan
# 7787   s7786  TV Show                    Zumbo's Just Desserts
# 7788   s7787    Movie  ZZ TOP: THAT LITTLE OL' BAND FROM TEXAS
#
#                Director                                               Cast  \
# 0                   NaN  João Miguel, Bianca Comparato, Michel Gomes, R...
# ...

# %%
data[data['Category']=='TV Show']['Country'].value_counts().head(5)
# Out:
# Country
# United States     705
# United Kingdom    204
# Japan             157
# South Korea       147
# India              71
# Name: count, dtype: int64

# %%
data[(data['Category']=='Movie')&(data['Director']=='Christopher Nolan')]
# Out:
#      Show_Id Category      Title           Director  \
# 2979   s2980    Movie  Inception  Christopher Nolan
#
#                                                    Cast  \
# 2979  Leonardo DiCaprio, Joseph Gordon-Levitt, Ellen...
#
#                             Country     Release_Date Rating Duration  \
# 2979  United States, United Kingdom  January 1, 2020  PG-13  148 min
#
#                                                  Type  \
# 2979  Action & Adventure, Sci-Fi & Fantasy, Thrillers
#
#                                             Description
# 2979  In this mind-bending sci-fi thriller, a man ru...

# %%
 data['Category'].value_counts()
# Out:
# Category
# Movie      5379
# TV Show    2410
# Name: count, dtype: int64

# %%
data.head()
# Out:
#   Show_Id Category  Title           Director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie  07:19  Jorge Michel Grau
# 2      s3    Movie  23:59       Gilbert Chan
# 3      s4    Movie      9        Shane Acker
# 4      s5    Movie     21     Robert Luketic
#
#                                                 Cast        Country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...         Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...         Mexico
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...      Singapore
# 3  Elijah Wood, John C. Reilly, Jennifer Connelly...  United States
# 4  Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...  United States
#
#         Release_Date Rating   Duration  \
# 0    August 14, 2020  TV-MA  4 Seasons
# 1  December 23, 2016  TV-MA     93 min
# 2  December 20, 2018      R     78 min
# 3  November 16, 2017  PG-13     80 min
# 4    January 1, 2020  PG-13    123 min
#
# ...

# %%
data['Rating'].value_counts()
# Out:
# Rating
# TV-MA       2865
# TV-14       1931
# TV-PG        806
# R            665
# PG-13        386
# TV-Y         280
# TV-Y7        271
# PG           247
# TV-G         194
# NR            84
# G             39
# TV-Y7-FV       6
# UR             5
# NC-17          3
# Name: count, dtype: int64

# %%
data['Rating'].value_counts().idxmax()
# Out:
# 'TV-MA'

# %%
data.head()
# Out:
#   Show_Id Category  Title           Director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie  07:19  Jorge Michel Grau
# 2      s3    Movie  23:59       Gilbert Chan
# 3      s4    Movie      9        Shane Acker
# 4      s5    Movie     21     Robert Luketic
#
#                                                 Cast        Country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...         Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...         Mexico
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...      Singapore
# 3  Elijah Wood, John C. Reilly, Jennifer Connelly...  United States
# 4  Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...  United States
#
#         Release_Date Rating   Duration  \
# 0    August 14, 2020  TV-MA  4 Seasons
# 1  December 23, 2016  TV-MA     93 min
# 2  December 20, 2018      R     78 min
# 3  November 16, 2017  PG-13     80 min
# 4    January 1, 2020  PG-13    123 min
#
# ...

# %%
data[data['Category']=='Movie']['Country'].value_counts().idxmax()
# Out:
# 'United States'

# %%
data.head()
# Out:
#   Show_Id Category  Title           Director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie  07:19  Jorge Michel Grau
# 2      s3    Movie  23:59       Gilbert Chan
# 3      s4    Movie      9        Shane Acker
# 4      s5    Movie     21     Robert Luketic
#
#                                                 Cast        Country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...         Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...         Mexico
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...      Singapore
# 3  Elijah Wood, John C. Reilly, Jennifer Connelly...  United States
# 4  Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...  United States
#
#         Release_Date Rating   Duration  \
# 0    August 14, 2020  TV-MA  4 Seasons
# 1  December 23, 2016  TV-MA     93 min
# 2  December 20, 2018      R     78 min
# 3  November 16, 2017  PG-13     80 min
# 4    January 1, 2020  PG-13    123 min
#
# ...

# %%
data['Director'].nunique()
# Out:
# 4050

# %%
data.head()
# Out:
#   Show_Id Category  Title           Director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie  07:19  Jorge Michel Grau
# 2      s3    Movie  23:59       Gilbert Chan
# 3      s4    Movie      9        Shane Acker
# 4      s5    Movie     21     Robert Luketic
#
#                                                 Cast        Country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...         Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...         Mexico
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...      Singapore
# 3  Elijah Wood, John C. Reilly, Jennifer Connelly...  United States
# 4  Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...  United States
#
#         Release_Date Rating   Duration  \
# 0    August 14, 2020  TV-MA  4 Seasons
# 1  December 23, 2016  TV-MA     93 min
# 2  December 20, 2018      R     78 min
# 3  November 16, 2017  PG-13     80 min
# 4    January 1, 2020  PG-13    123 min
#
# ...

# %%
# Assuming you have already read your data into 'data' DataFrame
# Previous code to extract year:
# data['Release_Year']=pd.to_datetime(data['Release_Date'],errors='coerce').dt.year

#Ensure 'Release_Year' column is created before filtering:
data['Release_Year'] = pd.to_datetime(data['Release_Date'], errors='coerce').dt.year # Extract year and create 'Release_Year' column

# Now you can filter:
filtered_data = data[(data['Category']=='TV Show') & (data['Release_Year']==2020)]
filtered_data
# Out:
#      Show_Id Category                                Title Director  \
# 0         s1  TV Show                                   3%      NaN
# 24       s25  TV Show  ​SAINT SEIYA: Knights of the Zodiac      NaN
# 26       s27  TV Show                             (Un)Well      NaN
# 29       s30  TV Show                             #blackAF      NaN
# 51       s52  TV Show                   100 Days My Prince      NaN
# ...      ...      ...                                  ...      ...
# 7740   s7739  TV Show                      Young Wallander      NaN
# 7748   s7747  TV Show                         دفعة القاهرة      NaN
# 7751   s7750  TV Show                            Yu-Gi-Oh!      NaN
# 7777   s7776  TV Show                           Zoids Wild      NaN
# 7787   s7786  TV Show                Zumbo's Just Desserts      NaN
#
#                                                    Cast         Country  \
# 0     João Miguel, Bianca Comparato, Michel Gomes, R...          Brazil
# ...

# %%
(data['Category']=='Movie') & (data['Release_Year'])>=(data['Release_Year'])
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 7784    False
# 7785    False
# 7786    False
# 7787    False
# 7788    False
# Length: 7789, dtype: bool

# %%
data[data['Director'].isna()]
# Out:
#      Show_Id Category                                Title Director  \
# 0         s1  TV Show                                   3%      NaN
# 11       s12  TV Show                                 1983      NaN
# 16       s17  TV Show                               Feb-09      NaN
# 19       s20    Movie                                  '89      NaN
# 24       s25  TV Show  ​SAINT SEIYA: Knights of the Zodiac      NaN
# ...      ...      ...                                  ...      ...
# 7777   s7776  TV Show                           Zoids Wild      NaN
# 7779   s7778  TV Show                          Zombie Dumb      NaN
# 7781   s7780  TV Show                            Zona Rosa      NaN
# 7786   s7785    Movie                    Zulu Man in Japan      NaN
# 7787   s7786  TV Show                Zumbo's Just Desserts      NaN
#
#                                                    Cast  \
# 0     João Miguel, Bianca Comparato, Michel Gomes, R...
# ...
